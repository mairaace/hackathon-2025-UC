# %% [markdown]
# ## Modelo TF-DF para obtener cursos similares basado en descripciones de curos
# 1. Este jupyter busca extaer lo que son las descripciones de todos los cursos ofg de la UC  mediante la API pública de OSUC
#
# 2. Ese jupyter entrena un model TF-DF para entregar cursos parecidos a otros basado en la descripción de los cursos

# %%
## librerías 
import requests
import ndjson
import pandas as pd
from typing import List, Dict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pickle

# %%
'''
Obtener siglas de los cursos
'''

# Leer el archivo NDJSON
with open('../data/courses-sections.ndjson', 'r', encoding='utf-8') as f:
    cursos_datos = ndjson.load(f)

# Filtrar: siglas con área no vacía
cursos_con_area = []

for curso in cursos_datos:
    area_curso = ""
    
    # Buscar la primera sección con área no vacía
    for section_key, section_data in curso.get('sections', {}).items():
        if section_data.get('area', '').strip():
            area_curso = section_data.get('area', '')
            break
    
    # Si encontramos área, agregar el curso
    if area_curso:
        cursos_con_area.append({
            'sigle': curso.get('sigle', '').lower(),  # Convertir a minúsculas
            'name': curso.get('name', ''),
            'area': area_curso
        })

# Crear DataFrame
df_cursos_filtrados = pd.DataFrame(cursos_con_area)

# Actualizar la lista CURSOS con las siglas en minúsculas
CURSOS = df_cursos_filtrados['sigle'].tolist()

# %%
df_cursos_filtrados.head()
# Out:
#      sigle                                               name   area
# 0  act1307  Comunicación Expresiva: Conciencia Vocal y Cor...  Artes
# 1  act1308                  Conciencia y Expresión del Cuerpo  Artes
# 2  act1309  Imaginarios para la Construcción del Teatro Ch...  Artes
# 3  act1311  Mitos Clásicos y Creación de Relatos en la Dra...  Artes
# 4  act1312  Performance Como Experiencia para la Transform...  Artes

# %%
# URL base de la API
BASE_URL = "https://buscaramos-v2-static-data.osuc.workers.dev/data"

def obtener_descripcion_curso(codigo_curso: str) -> Dict:
    """
    Hace un request a la API para obtener la descripción de un curso
    Retorna solo: sigle, name y description
    """
    try:
        url = f"{BASE_URL}/{codigo_curso}"
        response = requests.get(url, headers={"accept": "application/json"})
        response.raise_for_status()
        datos = response.json()
        
        # Buscar el área en df_cursos_filtrados
        area = df_cursos_filtrados[df_cursos_filtrados['sigle'] == codigo_curso.lower()]['area'].values
        area_curso = area[0] if len(area) > 0 else ""
        # Solo voy a extraer los campos que necesito, no la response completa
        return {
            "sigle": datos.get("sigle"),
            "name": datos.get("name"),
            "description": datos.get("description"),
            'area': area_curso
        }
    except requests.exceptions.RequestException as e:
        print(f"Error obteniendo {codigo_curso}: {e}")
        return None

#
datos_cursos = []

for curso in CURSOS:
    print(f"Obteniendo datos del curso: {curso}")
    datos = obtener_descripcion_curso(curso)
    if datos:
        datos_cursos.append(datos)
# Out:
# Obteniendo datos del curso: act1307
# Obteniendo datos del curso: act1308
# Obteniendo datos del curso: act1309
# Obteniendo datos del curso: act1311
# Obteniendo datos del curso: act1312
# Obteniendo datos del curso: act1313
# Obteniendo datos del curso: act1314
# Obteniendo datos del curso: act1315
# Obteniendo datos del curso: act1318
# Obteniendo datos del curso: act1319
# Obteniendo datos del curso: act1321
# Obteniendo datos del curso: aeu2003
# Obteniendo datos del curso: agc209
# Obteniendo datos del curso: agl253
# Obteniendo datos del curso: agl255
# Obteniendo datos del curso: aro105c
# Obteniendo datos del curso: aro105t
# Obteniendo datos del curso: aro107i
# Obteniendo datos del curso: aro114m
# Obteniendo datos del curso: aro115m
# Obteniendo datos del curso: aro120t
# Obteniendo datos del curso: aro122t
# Obteniendo datos del curso: aro123t
# Obteniendo datos del curso: aro124t
# Obteniendo datos del curso: aro125t
# Obteniendo datos del curso: ast101
# Obteniendo datos del curso: ast104
# Obteniendo datos del curso: arq2006
# Obteniendo datos del curso: arq2007
# Obteniendo datos del curso: arq2010
# Obteniendo datos del curso: bio011
# Obteniendo datos del curso: car0005
# Obteniendo datos del curso: car3000
# Obteniendo datos del curso: cco3321
# Obteniendo datos del curso: cdp001
# Obteniendo datos del curso: com903
# Obteniendo datos del curso: com909
# Obteniendo datos del curso: der102e
# Obteniendo datos del curso: der110e
# Obteniendo datos del curso: der113e
# Obteniendo datos del curso: dno048
# Obteniendo datos del curso: dno081
# Obteniendo datos del curso: dno092
# Obteniendo datos del curso: dno093
# Obteniendo datos del curso: dno158
# Obteniendo datos del curso: dpt5000
# Obteniendo datos del curso: dpt5050
# Obteniendo datos del curso: dpt5100
# Obteniendo datos del curso: dpt5200
# Obteniendo datos del curso: dpt5205
# Obteniendo datos del curso: dpt5206
# Obteniendo datos del curso: dpt5251
# Obteniendo datos del curso: dpt5453
# Obteniendo datos del curso: dpt5454
# Obteniendo datos del curso: dpt5456
# Obteniendo datos del curso: dpt5502
# Obteniendo datos del curso: dpt5705
# Obteniendo datos del curso: dpt5755
# Obteniendo datos del curso: dpt5756
# Obteniendo datos del curso: dpt5806
# Obteniendo datos del curso: dpt5807
# Obteniendo datos del curso: dpt5901
# Obteniendo datos del curso: dpt6000
# Obteniendo datos del curso: dpt6051
# Obteniendo datos del curso: dpt6100
# Obteniendo datos del curso: dpt6150
# Obteniendo datos del curso: dpt6270
# Obteniendo datos del curso: dpt6300
# Obteniendo datos del curso: dpt6302
# Obteniendo datos del curso: dpt6351
# Obteniendo datos del curso: dpt6381
# Obteniendo datos del curso: dpt6382
# Obteniendo datos del curso: dpt6384
# Obteniendo datos del curso: dpt6400
# Obteniendo datos del curso: dpt6500
# Obteniendo datos del curso: dpt6555
# Obteniendo datos del curso: dpt6560
# Obteniendo datos del curso: dpt6700
# Obteniendo datos del curso: dpt6755
# Obteniendo datos del curso: dpt6760
# Obteniendo datos del curso: dpt6805
# Obteniendo datos del curso: dpt6840
# Obteniendo datos del curso: dpt6900
# Obteniendo datos del curso: dpt7005
# Obteniendo datos del curso: dpt7055
# Obteniendo datos del curso: dpt7060
# Obteniendo datos del curso: dpt7160
# Obteniendo datos del curso: dpt7170
# Obteniendo datos del curso: dpt7260
# Obteniendo datos del curso: dpt7270
# Obteniendo datos del curso: dpt7355
# Obteniendo datos del curso: dpt7360
# Obteniendo datos del curso: dpt7375
# Obteniendo datos del curso: dpt7380
# Obteniendo datos del curso: dpt7460
# Obteniendo datos del curso: dpt7470
# Obteniendo datos del curso: dpt7525
# Obteniendo datos del curso: dpt7535
# Obteniendo datos del curso: dpt7665
# Obteniendo datos del curso: dpt7675
# Obteniendo datos del curso: dpt7710
# Obteniendo datos del curso: dpt7815
# Obteniendo datos del curso: dpt7825
# Obteniendo datos del curso: dpt7875
# Obteniendo datos del curso: dpt7885
# Obteniendo datos del curso: dpt7915
# Obteniendo datos del curso: dpt7925
# Obteniendo datos del curso: dpt7955
# Obteniendo datos del curso: dpt7960
# Obteniendo datos del curso: dpt8025
# Obteniendo datos del curso: dpt8035
# Obteniendo datos del curso: dpt8065
# Obteniendo datos del curso: dpt8075
# Obteniendo datos del curso: dpt8110
# Obteniendo datos del curso: dpt8165
# Obteniendo datos del curso: dpt8175
# Obteniendo datos del curso: dpt8310
# Obteniendo datos del curso: dpt8315
# Obteniendo datos del curso: dpt8415
# Obteniendo datos del curso: dpt8425
# Obteniendo datos del curso: dpt8455
# Obteniendo datos del curso: dpt9015
# Obteniendo datos del curso: dpt9035
# Obteniendo datos del curso: dpt9045
# Obteniendo datos del curso: dpt9055
# Obteniendo datos del curso: dpt9065
# Obteniendo datos del curso: dpt9100
# Obteniendo datos del curso: dpt9335
# Obteniendo datos del curso: eag110a
# Obteniendo datos del curso: eag120a
# Obteniendo datos del curso: eag170a
# Obteniendo datos del curso: eag190a
# Obteniendo datos del curso: edu023r
# Obteniendo datos del curso: edu124c
# Obteniendo datos del curso: edu21es
# Obteniendo datos del curso: edu222b
# Obteniendo datos del curso: edu224m
# Obteniendo datos del curso: edu324a
# Obteniendo datos del curso: edu424b
# Obteniendo datos del curso: eno2028
# Obteniendo datos del curso: enf1100
# Obteniendo datos del curso: enf1126
# Obteniendo datos del curso: eso008
# Obteniendo datos del curso: eso013
# Obteniendo datos del curso: eso015
# Obteniendo datos del curso: est210a
# Obteniendo datos del curso: eti1004
# Obteniendo datos del curso: euc8002
# Obteniendo datos del curso: fis0104
# Obteniendo datos del curso: fil2001
# Obteniendo datos del curso: fil2002
# Obteniendo datos del curso: fil2003
# Obteniendo datos del curso: fil2005
# Obteniendo datos del curso: fil2006
# Obteniendo datos del curso: fil2007
# Obteniendo datos del curso: fil2008
# Obteniendo datos del curso: fon103
# Obteniendo datos del curso: fon104
# Obteniendo datos del curso: geo623
# Obteniendo datos del curso: gob2018
# Obteniendo datos del curso: gob2019
# Obteniendo datos del curso: gob2020
# Obteniendo datos del curso: gob2021
# Obteniendo datos del curso: gob2022
# Obteniendo datos del curso: gob2023
# Obteniendo datos del curso: gob2026
# Obteniendo datos del curso: gob2027
# Obteniendo datos del curso: ibm1101
# Obteniendo datos del curso: ich100g
# Obteniendo datos del curso: icm100g
# Obteniendo datos del curso: icp0156
# Obteniendo datos del curso: icp0158
# Obteniendo datos del curso: icp0351
# Obteniendo datos del curso: icp0720
# Obteniendo datos del curso: ieu2002
# Obteniendo datos del curso: ieu2047
# Obteniendo datos del curso: ieu2048
# Obteniendo datos del curso: ieu2050
# Obteniendo datos del curso: ieu2051
# Obteniendo datos del curso: ieu2052
# Obteniendo datos del curso: ieu2067
# Obteniendo datos del curso: ieu2080
# Obteniendo datos del curso: ihi0211
# Obteniendo datos del curso: ihi0519
# Obteniendo datos del curso: ihi0520
# Obteniendo datos del curso: ihi0524
# Obteniendo datos del curso: ihi0528
# Obteniendo datos del curso: ihi0529
# Obteniendo datos del curso: ihi0534
# Obteniendo datos del curso: ihi0537
# Obteniendo datos del curso: ihi0538
# Obteniendo datos del curso: iic100g
# Obteniendo datos del curso: iic101g
# Obteniendo datos del curso: iic102g
# Obteniendo datos del curso: imt2000
# Obteniendo datos del curso: ing101g
# Obteniendo datos del curso: kin107
# Obteniendo datos del curso: let003g
# Obteniendo datos del curso: let004g
# Obteniendo datos del curso: let202g
# Obteniendo datos del curso: mat0100
# Obteniendo datos del curso: mat0123
# Obteniendo datos del curso: med836
# Obteniendo datos del curso: med838
# Obteniendo datos del curso: med842
# Obteniendo datos del curso: med863
# Obteniendo datos del curso: muc1000
# Obteniendo datos del curso: muc701
# Obteniendo datos del curso: muc859
# Obteniendo datos del curso: muc872
# Obteniendo datos del curso: muc957
# Obteniendo datos del curso: muc958
# Obteniendo datos del curso: muc959
# Obteniendo datos del curso: muc960
# Obteniendo datos del curso: nut1001
# Obteniendo datos del curso: nut1002
# Obteniendo datos del curso: odo702
# Obteniendo datos del curso: odo703
# Obteniendo datos del curso: psg001
# Obteniendo datos del curso: qim122
# Obteniendo datos del curso: qim124
# Obteniendo datos del curso: qim519
# Obteniendo datos del curso: rce1000
# Obteniendo datos del curso: sus1000
# Obteniendo datos del curso: sus2001
# Obteniendo datos del curso: sus2021
# Obteniendo datos del curso: sus2032
# Obteniendo datos del curso: sus2038
# Obteniendo datos del curso: sus2041
# Obteniendo datos del curso: sus2052
# Obteniendo datos del curso: sus2061
# Obteniendo datos del curso: sus2071
# Obteniendo datos del curso: sus2091
# Obteniendo datos del curso: sus2131
# Obteniendo datos del curso: sus2171
# Obteniendo datos del curso: sus2181
# Obteniendo datos del curso: sus2191
# Obteniendo datos del curso: ter001
# Obteniendo datos del curso: ter002
# Obteniendo datos del curso: ter003
# Obteniendo datos del curso: ter004
# Obteniendo datos del curso: ter006
# Obteniendo datos del curso: ter007
# Obteniendo datos del curso: ter008
# Obteniendo datos del curso: ter009
# Obteniendo datos del curso: tid201
# Obteniendo datos del curso: tsl589
# Obteniendo datos del curso: tsl590
# Obteniendo datos del curso: tsl596
# Obteniendo datos del curso: ttf010
# Obteniendo datos del curso: ttf012
# Obteniendo datos del curso: ttf019
# Obteniendo datos del curso: ttf026
# Obteniendo datos del curso: ttf036
# Obteniendo datos del curso: ttf038
# Obteniendo datos del curso: ttf068
# Obteniendo datos del curso: ttf069
# Obteniendo datos del curso: ttf073
# Obteniendo datos del curso: ttf079
# Obteniendo datos del curso: ttf080
# Obteniendo datos del curso: ttf083
# Obteniendo datos del curso: ttf085
# Obteniendo datos del curso: ttf087
# Obteniendo datos del curso: ttf091
# Obteniendo datos del curso: ttf115
# Obteniendo datos del curso: ttf116
# Obteniendo datos del curso: ttf118
# Obteniendo datos del curso: ttf201
# Obteniendo datos del curso: ttf202
# Obteniendo datos del curso: ttf204
# Obteniendo datos del curso: ttf205
# Obteniendo datos del curso: ttf206
# Obteniendo datos del curso: ttf207
# Obteniendo datos del curso: ttf208
# Obteniendo datos del curso: ttf209
# Obteniendo datos del curso: ttf210
# Obteniendo datos del curso: ttf213
# Obteniendo datos del curso: ttf215
# Obteniendo datos del curso: ttf217
# Obteniendo datos del curso: ttf218
# Obteniendo datos del curso: ttf220
# Obteniendo datos del curso: ttf222
# Obteniendo datos del curso: ttf226
# Obteniendo datos del curso: ttf228
# Obteniendo datos del curso: ttf229
# Obteniendo datos del curso: ttf233
# Obteniendo datos del curso: ttf235
# Obteniendo datos del curso: vet1601
# Obteniendo datos del curso: vil629
# Obteniendo datos del curso: vil630
# Obteniendo datos del curso: vil633
# Obteniendo datos del curso: vil634
# Obteniendo datos del curso: vil635
# Obteniendo datos del curso: vil636

# %%
# Convertir a DataFrame de pandas
df_cursos = pd.DataFrame(datos_cursos)

# Limpiar espacios múltiples en la columna description
df_cursos['description'] = df_cursos['description'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# ### Parte II: Entrenamiento de modelo TF-DF

# %%
df_cursos['sigle'] = df_cursos['sigle'].str.lower()

df_cursos['description'] = df_cursos['description'].fillna('')

tfidf = TfidfVectorizer(
    max_features=200,  # límite de palablas, con 200 funciona bastante bien
    lowercase=True,
    min_df=1
)


tfidf_matrix = tfidf.fit_transform(df_cursos['description'])

# Calcular similitud coseno entre todos los cursos
similarity_matrix = cosine_similarity(tfidf_matrix)


def recomendar_cursos(codigo_curso: str, n_recomendaciones: int = 5):
    """
    Recomienda cursos similares basado en TF-IDF
    """
    try:
    
        idx = df_cursos[df_cursos['sigle'] == codigo_curso.lower()].index[0]
        
        # Obtener similitudes del curso con todos los demás
        similitudes = similarity_matrix[idx]
        
        # Ordenar en orden descendente para obtener el de mayor similitud arriba
        indices_similares = np.argsort(similitudes)[::-1][1:n_recomendaciones+1]
        
        #crear el df
        recomendaciones = df_cursos.iloc[indices_similares][['sigle', 'name', 'area']].copy()
        recomendaciones['similaridad'] = similitudes[indices_similares]
        
        return recomendaciones
    except IndexError:
        # Si no se encuentra en curso en la lista
        print(f"Curso {codigo_curso} no encontrado")
        return None

# Uso 

'''
esto es como , lo que hay en los pickles : 

tfidf_matrix = tfidf.fit_transform(df_cursos['description'])
similarity_matrix = cosine_similarity(tfidf_matrix)

y como se puede ver en la función recomendar_cursos, similarity_matrix es la clave 
para encontrar las similitudes, habría que ver como emplementar esto (que es el módelo basicamente)
en la website, abajito hay un ejemplo de ocmo funciona  recomendar cursos. 

el df 
'''
print("Recomendaciones para act1307:")
recomendar_cursos('act1307', n_recomendaciones=5)
# Out:
# Recomendaciones para act1307:
#        sigle                                               name  \
# 4    act1312  Performance Como Experiencia para la Transform...
# 218   psg001  Lengua de Señas Chilena: la Comunidad Sorda y ...
# 3    act1311  Mitos Clásicos y Creación de Relatos en la Dra...
# 10   act1321   El Diálogo Teatral para la Comunicación Escénica
# 153  fil2006                    Introducción a la Argumentación
#
#                   area  similaridad
# 4                Artes     0.578127
# 218  Ciencias Sociales     0.552720
# 3                Artes     0.542723
# 10               Artes     0.537673
# 153        Humanidades     0.532529

# %%
# Guardar el modelo TF-IDF
pickle.dump(tfidf, open('tfidf_model.pkl', 'wb'))

# matriz sw aimilirud
pickle.dump(similarity_matrix, open('similarity_matrix.pkl', 'wb'))

# Guardar el DataFrame
df_cursos.to_csv('../data/df_cursos.csv', index=False)
# Guardar como JSON
df_cursos.to_json('../data/df_cursos.json', orient='records', indent=2, force_ascii=False)
